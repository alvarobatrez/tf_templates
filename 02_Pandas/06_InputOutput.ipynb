# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# '/home/alvaro/tf_templates/02_Pandas'

# %%
ls
# Out:
# 01_Series.ipynb      03_MissingData.ipynb  05_Operations.ipynb
# 02_Dataframes.ipynb  04_GroupBy.ipynb      06_InputOutput.ipynb

# %%
df = pd.read_csv('/home/alvaro/tf_templates/DATA/Top-Largest-Universities.csv')
df
# Out:
#     Rank                                        Institution  \
# 0      1             Indira Gandhi National Open University
# 1      2               California Community Colleges System
# 2      3                    National University, Bangladesh
# 3      4                                 Anadolu University
# 4      5                       Allama Iqbal Open University
# ..   ...                                                ...
# 79    80                              University of Toronto
# 80    81                   Complutense University of Madrid
# 81    82                              Farhangian University
# 82    83                                University of Hagen
# 83    84   Academic Center for Education, Culture and Re...
#
#                      Location      Continent Founded Affiliation  \
# 0            New Delhi, India           Asia    1985      Public
# 1   California, United States  North America    1967      Public
# ...

# %%
df.to_csv('/home/alvaro/tf_templates/Top-Largest-Universities-COPY.csv',index=False)

# %%
banks = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
banks
# Out:
# [                         Bank NameBank       CityCity StateSt  CertCert  \
#  0                        Citizens Bank       Sac City      IA      8758
#  1             Heartland Tri-State Bank        Elkhart      KS     25851
#  2                  First Republic Bank  San Francisco      CA     59017
#  3                       Signature Bank       New York      NY     57053
#  4                  Silicon Valley Bank    Santa Clara      CA     24735
#  ..                                 ...            ...     ...       ...
#  563                 Superior Bank, FSB       Hinsdale      IL     32646
#  564                Malta National Bank          Malta      OH      6629
#  565    First Alliance Bank & Trust Co.     Manchester      NH     34264
#  566  National State Bank of Metropolis     Metropolis      IL      3815
#  567                   Bank of Honolulu       Honolulu      HI     21029
#
#                   Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
banks[0].head()
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0             Citizens Bank       Sac City      IA      8758
# 1  Heartland Tri-State Bank        Elkhart      KS     25851
# 2       First Republic Bank  San Francisco      CA     59017
# 3            Signature Bank       New York      NY     57053
# 4       Silicon Valley Bank    Santa Clara      CA     24735
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0            Iowa Trust & Savings Bank    November 3, 2023     10545
# 1               Dream First Bank, N.A.       July 28, 2023     10544
# 2            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 3                  Flagstar Bank, N.A.      March 12, 2023     10540
# 4  First–Citizens Bank & Trust Company      March 10, 2023     10539
