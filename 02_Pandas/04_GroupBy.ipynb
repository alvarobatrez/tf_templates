# %%
import pandas as pd

# %%
df = pd.read_csv('/home/alvaro/tf_templates/DATA/Top-Largest-Universities.csv')

# %%
df.head()
# Out:
#    Rank                             Institution                   Location  \
# 0     1  Indira Gandhi National Open University           New Delhi, India
# 1     2    California Community Colleges System  California, United States
# 2     3         National University, Bangladesh        Gazipur, Bangladesh
# 3     4                      Anadolu University          Eskişehir, Turkey
# 4     5            Allama Iqbal Open University        Islamabad, Pakistan
#
#        Continent Founded Affiliation Distance / In-Person  Enrollment
# 0           Asia    1985      Public   Distance/In-Person     7140000
# 1  North America    1967      Public            In-Person     2133846
# 2           Asia    1992      Public            In-Person     2097182
# 3           Asia    1958      Public   Distance/In-Person     1974343
# 4           Asia    1974      Public   Distance/In-Person     1027000

# %%
df.groupby('Founded')

# %%
df.groupby('Continent').min()
# Out:
#                Rank                              Institution  \
# Continent
# Africa           17                     Ain Shams University
# Asia              1   Indira Gandhi National Open University
# Europe           33         Complutense University of Madrid
# Global            7                 Laureate Education, Inc.
# North America     2   Autonomous University of Santo Domingo
# South America    29                 Estácio de Sá University
#
#                                 Location Founded Affiliation  \
# Continent
# Africa                      Cairo, Egypt    1873      Public
# Asia                   Bangkok, Thailand    1857     Private
# Europe                  Belgrade, Serbia    1293     Private
# Global                     International    1999     Private
# North America  California, United States    1538     Private
# South America    Buenos Aires, Argentina    1613     Private
#
#               Distance / In-Person  Enrollment
# Continent
# ...

# %%
df.groupby(['Continent','Affiliation']).min()
# Out:
#                            Rank  \
# Continent     Affiliation
# Africa        Public         17
# Asia          Private         6
#               Public          1
# Europe        Private        75
#               Public         33
# Global        Private         7
# North America Private        53
#               Public          2
# South America Private        38
#               Public         29
#
#                                                                  Institution  \
# Continent     Affiliation
# Africa        Public                                    Ain Shams University
# Asia          Private       Academic Center for Education, Culture and Re...
#               Public                  Indira Gandhi National Open University
# Europe        Private        IU International University of Applied Sciences
#               Public                        Complutense University of Madrid
# Global        Private                               Laureate Education, Inc.
# ...

# %%
df.groupby('Continent').describe().transpose()
# Out:
# Continent                Africa          Asia         Europe    Global  \
# Rank       count       4.000000  3.100000e+01      11.000000       1.0
#            mean       31.250000  3.280645e+01      63.000000       7.0
#            std        15.195942  2.560263e+01      17.714401       NaN
#            min        17.000000  1.000000e+00      33.000000       7.0
#            25%        20.750000  1.250000e+01      48.500000       7.0
#            50%        28.500000  2.400000e+01      67.000000       7.0
#            75%        39.000000  5.250000e+01      77.500000       7.0
#            max        51.000000  8.400000e+01      83.000000       7.0
# Enrollment count       4.000000  3.100000e+01      11.000000       1.0
#            mean   340550.000000  7.021327e+05  139182.363636  875000.0
#            std    155755.823861  1.289412e+06   58901.765404       NaN
#            min    170000.000000  6.000000e+04   76096.000000  875000.0
# ...
