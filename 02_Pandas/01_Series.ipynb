# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
myList = [5,10,15]
a = np.array([5,10,15])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data=myList)
# Out:
# 0     5
# 1    10
# 2    15
# dtype: int64

# %%
pd.Series(data=myList, index=labels)
# Out:
# a     5
# b    10
# c    15
# dtype: int64

# %%
pd.Series(a)
# Out:
# 0     5
# 1    10
# 2    15
# dtype: int64

# %%
pd.Series(data=a, index=labels)
# Out:
# a     5
# b    10
# c    15
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=['dog',13,3.14])
# Out:
# 0     dog
# 1      13
# 2    3.14
# dtype: object

# %%
pd.Series([sum, print, len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
salesQ1 = pd.Series(data=[250,300,200,450],index=['Mex','Col','Arg','Chi'])
salesQ1
# Out:
# Mex    250
# Col    300
# Arg    200
# Chi    450
# dtype: int64

# %%
salesQ2 = pd.Series(data=[250,300,200,600],index=['Mex','Col','Arg','Bra'])
salesQ2
# Out:
# Mex    250
# Col    300
# Arg    200
# Bra    600
# dtype: int64

# %%
salesQ1['Arg']
# Out:
# 200

# %%
salesQ1 +  salesQ2
# Out:
# Arg    400.0
# Bra      NaN
# Chi      NaN
# Col    600.0
# Mex    500.0
# dtype: float64
